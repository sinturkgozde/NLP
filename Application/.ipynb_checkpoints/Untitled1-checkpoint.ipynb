# %%
import wikipedia
import work

data = wikipedia.page("America").content.replace("\n","").replace("=","").replace('\\',"").split(".")

print work.extractSimilarSentences("America","discover",data,work.model)
# Out:
# [u'The United States of America (commonly referred to as the United States, U', u'S', u', USA, or America), is a federal republic composed of 50 states, a federal district of Washington, D', u'C', u', five major territories, and various possessions', u' The 48 contiguous states and Washington, D', u'C', u', are in central North America between Canada and Mexico', u' The state of Alaska is in the northwestern part of North America and the state of Hawaii is an archipelago in the mid-Pacific', u' The territories are scattered about the Pacific Ocean and the Caribbean Sea', u' At 3', u'8 million square miles (9', u"9 million km2) and with over 320 million people, the country is the world's third largest by total area (fourth largest by land area) and the third most populous", u" It is one of the world's most ethnically diverse and multicultural nations, the product of large-scale immigration from many countries", u' The geography and climate of the United States are also extremely diver
# ...
